# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
# CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Flatten labels
y_train = y_train.flatten()
y_test = y_test.flatten()

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i]])
    plt.axis('off')
plt.show()

# %%
model = keras.Sequential([

    data_augmentation,

    layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64
)
# Out:
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.3525 - loss: 1.7956 - val_accuracy: 0.4536 - val_loss: 1.4935
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4436 - loss: 1.5356 - val_accuracy: 0.5422 - val_loss: 1.2782
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4936 - loss: 1.4115 - val_accuracy: 0.5690 - val_loss: 1.2026
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5331 - loss: 1.3094 - val_accuracy: 0.5850 - val_loss: 1.1692
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5706 - loss: 1.2258 - val_accuracy: 0.6268 - val_loss: 1.0688
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5950 - loss: 1.1662 - val_accuracy: 0.6582 - val_loss: 0.9948
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.6091 - loss: 1.1211 - val_accuracy: 0.6284 - val_loss: 1.1077
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.6249 - loss: 1.0794 - val_accuracy: 0.6282 - val_loss: 1.0997
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6388 - loss: 1.0492 - val_accuracy: 0.6642 - val_loss: 0.9809
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6468 - loss: 1.0231 - val_accuracy: 0.6918 - val_loss: 0.9032
# Epoch 11/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6602 - loss: 0.9914 - val_accuracy: 0.6828 - val_loss: 0.9433
# Epoch 12/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.6657 - loss: 0.9697 - val_accuracy: 0.6760 - val_loss: 0.9690
# Epoch 13/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.6768 - loss: 0.9407 - val_accuracy: 0.7046 - val_loss: 0.8873
# Epoch 14/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6822 - loss: 0.9298 - val_accuracy: 0.7108 - val_loss: 0.8417
# Epoch 15/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6918 - loss: 0.9005 - val_accuracy: 0.6562 - val_loss: 1.0475
# Epoch 16/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6970 - loss: 0.8826 - val_accuracy: 0.7294 - val_loss: 0.7961
# Epoch 17/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.7046 - loss: 0.8631 - val_accuracy: 0.7384 - val_loss: 0.7651
# Epoch 18/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.7081 - loss: 0.8540 - val_accuracy: 0.7470 - val_loss: 0.7462
# Epoch 19/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7127 - loss: 0.8445 - val_accuracy: 0.7368 - val_loss: 0.8002
# Epoch 20/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7164 - loss: 0.8360 - val_accuracy: 0.7404 - val_loss: 0.7596

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7317 - loss: 0.7914
# Test Accuracy: 0.7317000031471252

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
y_pred = np.argmax(model.predict(x_test), axis=1)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.72      0.81      0.76      1000
#   automobile       0.86      0.85      0.85      1000
#         bird       0.69      0.63      0.66      1000
#          cat       0.59      0.49      0.54      1000
#         deer       0.74      0.61      0.67      1000
#          dog       0.70      0.62      0.66      1000
#         frog       0.73      0.81      0.77      1000
#        horse       0.75      0.82      0.79      1000
#         ship       0.89      0.78      0.83      1000
#        truck       0.66      0.89      0.76      1000
#
#     accuracy                           0.73     10000
#    macro avg       0.73      0.73      0.73     10000
# weighted avg       0.73      0.73      0.73     10000

# %%
index = 10

plt.imshow(x_test[index])
plt.title(f"Actual: {class_names[y_test[index]]}")

pred = np.argmax(model.predict(x_test[index].reshape(1,32,32,3)))
print("Predicted:", class_names[pred])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Predicted: airplane
